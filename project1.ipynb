# %%
import pandas as pd

# %%
import requests

# %%
response =  requests.get('https://api.deezer.com/search?q=eminem')

# %%
response
# Out:
# <Response [200]>

# %%
d = response.json()

# %%
d
# Out:
# {'data': [{'id': 916424,
#    'readable': True,
#    'title': 'Without Me',
#    'title_short': 'Without Me',
#    'title_version': '',
#    'isrc': 'USIR10211038',
#    'link': 'https://www.deezer.com/track/916424',
#    'duration': 290,
#    'rank': 961431,
#    'explicit_lyrics': True,
#    'explicit_content_lyrics': 1,
#    'explicit_content_cover': 0,
#    'preview': 'https://cdnt-preview.dzcdn.net/api/1/1/a/e/b/0/aeb58f2f63ee57fb9c47cbe8fb5ccdaa.mp3?hdnea=exp=1785954619~acl=/api/1/1/a/e/b/0/aeb58f2f63ee57fb9c47cbe8fb5ccdaa.mp3*~data=user_id=0,application_id=42~hmac=ab1b319fde1b8ba77366b593efaa516c13584da5b5dc257561859951e19398da',
#    'md5_image': 'ec3c8ed67427064c70f67e5815b74cef',
#    'artist': {'id': 13,
#     'name': 'Eminem',
#     'link': 'https://www.deezer.com/artist/13',
#     'picture': 'https://api.deezer.com/artist/13/image',
#     'picture_small': 'https://cdn-images.dzcdn.net/images/artist/0f30bbd33a680030054af004d698d6ac/56x56-000000-80-0-0.jpg',
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
temp = pd.DataFrame(response.json()['data'])[['id','title','link','duration', 'rank']]

# %%
temp
# Out:
#             id                                   title  \
# 0       916424                              Without Me
# 1      6461440                    Love The Way You Lie
# 2       916445                         Till I Collapse
# 3     72160317                             The Monster
# 4      1109731                           Lose Yourself
# 5      6461432                              Not Afraid
# 6      1109739                             Mockingbird
# 7       916427                                Superman
# 8       979041                      Smack That (Clean)
# 9      1109737                     The Real Slim Shady
# 10      916426                     Sing For The Moment
# 11   854914322                                Godzilla
# 12     1109730                                    Stan
# 13  2825782592                                 Houdini
# 14   128743587                   What's The Difference
# 15   128743593                        Forgot About Dre
# ...

# %%
temp.shape
# Out:
# (25, 5)

# %%
for i in range(1,205):
    response = requests.get('https://api.deezer.com/search?q=eminem'.format(i))
    tem_df= pd.DataFrame(response.json()['data'])[['id','title','link','duration', 'rank']]
    df = pd.concat([df, tem_df], ignore_index=True)

# %%
df.shape
# Out:
# (10225, 5)

# %%
df.to_csv('music.csv')

# %%
pd
# Out:
# <module 'pandas' from 'd:\\ProgramData\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
import seaborn as sns

# %%
t= sns.load_dataset('titanic')

# %%
#how much data is big?
t.shape
# Out:
# (891, 15)

# %%
#how data looks like
t.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
t.sample(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 392         0       3  male  28.0      2      0   7.9250        S  Third  man
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
#
#      adult_male deck  embark_town alive  alone
# 392        True  NaN  Southampton    no  False
# 96         True    A    Cherbourg    no   True

# %%
#data contains null values 
t.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#is data contains duplicated values
t.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
#how data is look like mathematically?
t.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#info of data
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#data correlation
t.corr(numeric_only=True)
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %% [markdown]
# univarient analysis

# %%
#categorical data

# %%
#---countplot

# %% [markdown]
# t.head(6)

# %%
sns.countplot(x='alone',data=t,hue='sex')
# Out:
# <Axes: xlabel='alone', ylabel='count'>

# %%
#--------piechart

# %%
import matplotlib.pyplot as plt

# %%
t['pclass'].value_counts().plot(kind='pie',autopct='%2f')
# Out:
# <Axes: ylabel='count'>

# %%
t['alive'].value_counts().plot(kind='pie',autopct='%2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# numerical data

# %%
#boxplot

# %%
plt.hist(t['age'],bins=9)
# Out:
# (array([ 62.,  77., 180., 178., 102.,  65.,  35.,  13.,   2.]),
#  array([ 0.42      ,  9.26222222, 18.10444444, 26.94666667, 35.78888889,
#         44.63111111, 53.47333333, 62.31555556, 71.15777778, 80.        ]),
#  <BarContainer object of 9 artists>)

# %%
#distplot

# %%
sns.distplot(t['age'],hist=False)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_12784\16320956.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(t['age'],hist=False)
# <Axes: xlabel='age', ylabel='Density'>

# %%
#-------boxplot

# %%
sns.boxplot(t['age'])
# Out:
# <Axes: ylabel='age'>

# %%
#baivarient analysis

# %%
tip= sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
i= sns.load_dataset('iris')

# %%
i.sample(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 54            6.5          2.8           4.6          1.5  versicolor
# 10            5.4          3.7           1.5          0.2      setosa
# 110           6.5          3.2           5.1          2.0   virginica
# 111           6.4          2.7           5.3          1.9   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 87            6.3          2.3           4.4          1.3  versicolor

# %%
f= sns.load_dataset('flights')

# %%
f.head(3)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132

# %%
sns.barplot(data=tip,x='sex', y='tip',hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.scatterplot(data=tip,x='total_bill', y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=f,x='year', y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.boxplot(data=tip,x='sex', y='tip',hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.distplot(t[t['survived']==0]['age'],hist=False)
sns.distplot(t[t['survived']==1]['age'],hist=False)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_12784\2706741314.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(t[t['survived']==0]['age'],hist=False)
# C:\Users\me\AppData\Local\Temp\ipykernel_12784\2706741314.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
pd.crosstab
